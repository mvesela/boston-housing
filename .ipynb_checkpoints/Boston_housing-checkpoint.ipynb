# %%
import pandas as pd
import sklearn
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = load_boston()
housing = pd.DataFrame(data=data.data, columns=data.feature_names)
housing['target'] = pd.Series(data.target)
print(housing.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %% [markdown]
# ## Labels description

# %%
pd.set_option("max_colwidth", 9999)
pd.set_option("max_columns", 9999)
desc = load_boston().DESCR
description = pd.Series(desc).str.split(pat='\n',expand=True)
description
# Out:
#                      0 1                            2  \
# 0  .. _boston_dataset:    Boston house prices dataset
#
#                              3 4                                5 6  \
# 0  ---------------------------    **Data Set Characteristics:**
#
#                                 7 8  \
# 0      :Number of Instances: 506
#
#                                                                                                                   9  \
# 0      :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#   10                                      11  \
# 0         :Attribute Information (in order):
#
#                                                  12  \
# 0          - CRIM     per capita crime rate by town
#
#                                                                                     13  \
# 0          - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#
#                                                                     14  \
# 0          - INDUS    proportion of non-retail business acres per town
#
#                                                                                          15  \
# 0          - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#
#                                                                       16  \
# 0          - NOX      nitric oxides concentration (parts per 10 million)
#
#                                                         17  \
# 0          - RM       average number of rooms per dwelling
#
#                                                                           18  \
# 0          - AGE      proportion of owner-occupied units built prior to 1940
#
#                                                                         19  \
# 0          - DIS      weighted distances to five Boston employment centres
#
#                                                              20  \
# 0          - RAD      index of accessibility to radial highways
#
#                                                             21  \
# 0          - TAX      full-value property-tax rate per $10,000
#
#                                                22  \
# 0          - PTRATIO  pupil-teacher ratio by town
#
#                                                                                   23  \
# 0          - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#
#                                                     24  \
# 0          - LSTAT    % lower status of the population
#
#                                                                    25 26  \
# 0          - MEDV     Median value of owner-occupied homes in $1000's
#
#                                     27 28  \
# 0      :Missing Attribute Values: None
#
#                                                29 30  \
# 0      :Creator: Harrison, D. and Rubinfeld, D.L.
#
#                                           31  \
# 0  This is a copy of UCI ML housing dataset.
#
#                                                                    32 33 34  \
# 0  https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#                                                                                                    35  \
# 0  This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
#   36  \
# 0
#
#                                                                          37  \
# 0  The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
#
#                                                                           38  \
# 0  prices and the demand for clean air', J. Environ. Economics & Management,
#
#                                                                               39  \
# 0  vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
#
#                                                                            40  \
# 0  ...', Wiley, 1980.   N.B. Various transformations are used in the table on
#
#                              41 42  \
# 0  pages 244-261 of the latter.
#
#                                                                                                   43  \
# 0  The Boston house-price data has been used in many machine learning papers that address regression
#
#              44     45                     46 47  \
# 0  problems.            .. topic:: References
#
#                                                                                                                                       48  \
# 0     - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#
#                                                                                                                                                                                                                      49  \
# 0     - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.
#
#   50
# 0

# %% [markdown]
# ## Correlation matrix
# As we can see the LSTAT and RM are the two features which are highly correcalted with the target so we choose these two for prediction. Also it's vital to exclude the features that are higly correlated to each other such as RAD and TAX - use only one of those if higly correlated with the target.

# %%
corr = housing.corr()
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null float64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null float64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# target     506 non-null float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT      target
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
housing_X = housing.drop(columns=['target','TAX'])
X = housing_X.values
y = housing['target'].values
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %%
linreg = LinearRegression()
linreg.fit(X_train,y_train)
y_pred = linreg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
MSE = mean_squared_error(y_pred,y_test)
print(MSE)
# Out:
# 22.474267022889915

# %%
RMSE = np.sqrt(MSE)
RMSE
# Out:
# 4.740703220292314
